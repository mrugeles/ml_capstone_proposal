# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/mrugeles/ml_capstone_proposal/blob/master/CNNTestArchitectures.ipynb)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# <table border="1">
#   <tr>
#     <th>Model</th>
#     <th>Chart</th>
#  </tr>
# <tr>
#    <td >
#      <pre>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 224, 224, 16)      208
# =================================================================
# global_average_pooling2d_2 ( (None, 16)                0
# =================================================================
# dense_2 (Dense)              (None, 133)               2261
# =================================================================
# Total params: 2,469
# Trainable params: 2,469
# Non-trainable params: 0
# Time/Epoch: 19s
# Test accuracy: 3.3493%
# __________________________
#      </pre>
#    <td> <img src="http://mrugeles.github.io/images/Model1.png"/> </td>
#  </tr>
# <tr>
#    <td >
#      <pre>
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 224, 224, 16)      208
# =================================================================
# conv2d_5 (Conv2D)            (None, 224, 224, 16)      1040
# =================================================================
# global_average_pooling2d_3 ( (None, 16)                0
# =================================================================
# dense_3 (Dense)              (None, 133)               2261
# =================================================================
# Total params: 3,509
# Trainable params: 3,509
# Non-trainable params: 0
# Avg Time/Epoch: 19s
# Test accuracy: 3.7081%
#      </pre>
#    <td> <img src="http://mrugeles.github.io/images/Model2.png"/> </td>
#  </tr>
# <tr>
#    <td >
#      <pre>
# Model 3
#
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 224, 224, 16)      208
# =================================================================
# conv2d_10 (Conv2D)           (None, 224, 224, 16)      1040
# =================================================================
# conv2d_11 (Conv2D)           (None, 224, 224, 16)      1040
# =================================================================
# global_average_pooling2d_5 ( (None, 16)                0
# =================================================================
# dense_5 (Dense)              (None, 133)               2261
# =================================================================
# Total params: 4,549
# Trainable params: 4,549
# Non-trainable params: 0
# Avg Time/Epoch: 29s
# Test accuracy:4.6651%
# =================================================================
#      </pre>
#    <td> <img src="http://mrugeles.github.io/images/Model3.png"/> </td>
#  </tr>
# <tr>
#    <td >
#      <pre>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 224, 224, 16)      208
# =================================================================
# conv2d_13 (Conv2D)           (None, 224, 224, 16)      1040
# =================================================================
# conv2d_14 (Conv2D)           (None, 224, 224, 16)      1040
# =================================================================
# conv2d_15 (Conv2D)           (None, 224, 224, 16)      1040
# =================================================================
# global_average_pooling2d_6 ( (None, 16)                0
# =================================================================
# dense_6 (Dense)              (None, 133)               2261
# =================================================================
# Total params: 5,589
# Trainable params: 5,589
# Non-trainable params: 0
# Avg Time/Epoch: 38s
# Test accuracy: 4.7847%
# =================================================================
#      </pre>
#    <td> <img src="http://mrugeles.github.io/images/Model4.png"/> </td>
#  </tr>
# <tr>
#    <td >
#      <pre>
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 224, 224, 16)      208
# =================================================================
# conv2d_21 (Conv2D)           (None, 224, 224, 16)      1040
# =================================================================
# max_pooling2d_3 (MaxPooling2 (None, 112, 112, 16)      0
# =================================================================
# conv2d_22 (Conv2D)           (None, 112, 112, 32)      2080
# =================================================================
# conv2d_23 (Conv2D)           (None, 112, 112, 32)      4128
# =================================================================
# max_pooling2d_4 (MaxPooling2 (None, 56, 56, 32)        0
# =================================================================
# global_average_pooling2d_8 ( (None, 32)                0
# =================================================================
# dense_8 (Dense)              (None, 133)               4389
# =================================================================
# Total params: 11,845
# Trainable params: 11,845
# Non-trainable params: 0
# Avg Time/Epoch: 27s
# Test accuracy: 6.4593%
# =================================================================
#
#      </pre>
#    <td> <img src="http://mrugeles.github.io/images/Model5.png"/> </td>
#  </tr>
# <tr>
#    <td >
#      <pre>
# =================================================================
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 224, 224, 16)      208
# =================================================================
# conv2d_25 (Conv2D)           (None, 224, 224, 16)      1040
# =================================================================
# max_pooling2d_5 (MaxPooling2 (None, 112, 112, 16)      0
# =================================================================
# conv2d_26 (Conv2D)           (None, 112, 112, 32)      2080
# =================================================================
# conv2d_27 (Conv2D)           (None, 112, 112, 32)      4128
# =================================================================
# max_pooling2d_6 (MaxPooling2 (None, 56, 56, 32)        0
# =================================================================
# conv2d_28 (Conv2D)           (None, 56, 56, 64)        8256
# =================================================================
# conv2d_29 (Conv2D)           (None, 56, 56, 64)        16448
# =================================================================
# max_pooling2d_7 (MaxPooling2 (None, 28, 28, 64)        0
# =================================================================
# global_average_pooling2d_9 ( (None, 64)                0
# =================================================================
# dense_9 (Dense)              (None, 133)               8645
# =================================================================
# Total params: 40,805
# Trainable params: 40,805
# Non-trainable params: 0
# Avg Time/Epoch: 32s
# Test accuracy: 11.9617%
# =================================================================
#      </pre>
#    <td> <img src="http://mrugeles.github.io/images/Model6.png"/> </td>
#  </tr>
# <tr>
#    <td >
#      <pre>
# _________________________________________________________________
# Model 7:
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 224, 224, 16)      208
# =================================================================
# conv2d_37 (Conv2D)           (None, 224, 224, 16)      1040
# =================================================================
# max_pooling2d_11 (MaxPooling (None, 112, 112, 16)      0
# =================================================================
# conv2d_38 (Conv2D)           (None, 112, 112, 32)      2080
# =================================================================
# conv2d_39 (Conv2D)           (None, 112, 112, 32)      4128
# =================================================================
# max_pooling2d_12 (MaxPooling (None, 56, 56, 32)        0
# =================================================================
# conv2d_40 (Conv2D)           (None, 56, 56, 64)        8256
# =================================================================
# conv2d_41 (Conv2D)           (None, 56, 56, 64)        16448
# =================================================================
# max_pooling2d_13 (MaxPooling (None, 28, 28, 64)        0
# =================================================================
# dropout_2 (Dropout)          (None, 28, 28, 64)        0
# =================================================================
# global_average_pooling2d_11  (None, 64)                0
# =================================================================
# dense_11 (Dense)             (None, 133)               8645
# =================================================================
# Total params: 40,805
# Trainable params: 40,805
# Non-trainable params: 0
# Avg Time/Epoch: 32s
# Test accuracy: 12.5598%
# =================================================================
#      </pre>
#    <td> <img src="http://mrugeles.github.io/images/Model7.png"/> </td>
#  </tr>
#
#   <tr>
#    <td >
#      <pre>
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_54 (Conv2D)           (None, 224, 224, 16)      208
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 224, 224, 16)      1040
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 112, 112, 16)      0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 112, 112, 32)      2080
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 112, 112, 32)      4128
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 56, 56, 64)        8256
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 56, 56, 64)        16448
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 28, 28, 64)        0
# _________________________________________________________________
# global_average_pooling2d_14  (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 133)               8645
# =================================================================
# Total params: 40,805
# Trainable params: 40,805
# Non-trainable params: 0
# Avg Time/Epoch: 34s
# Test accuracy: 11.1244%
# __________________________________________
#      </pre>
#    <td> <img src="http://mrugeles.github.io/images/Model8.png"/> </td>
#  </tr>
#   </table>
